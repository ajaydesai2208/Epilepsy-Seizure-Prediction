# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Performing EDA

# %%
df = pd.read_csv('data.csv') #reading data

# %%
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %% [markdown]
# #### Checking for null values

# %%
df.isnull()
# Out:
#        Unnamed: 0     X1     X2     X3     X4     X5     X6     X7     X8  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False  False  False  False  False  False  False  False  False
# 4           False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11495       False  False  False  False  False  False  False  False  False
# 11496       False  False  False  False  False  False  False  False  False
# 11497       False  False  False  False  False  False  False  False  False
# 11498       False  False  False  False  False  False  False  False  False
# 11499       False  False  False  False  False  False  False  False  False
#
#           X9  ...   X170   X171   X172   X173   X174   X175   X176   X177  \
# 0      False  ...  False  False  False  False  False  False  False  False
# 1      False  ...  False  False  False  False  False  False  False  False
# 2      False  ...  False  False  False  False  False  False  False  False
# 3      False  ...  False  False  False  False  False  False  False  False
# 4      False  ...  False  False  False  False  False  False  False  False
# ...      ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11495  False  ...  False  False  False  False  False  False  False  False
# 11496  False  ...  False  False  False  False  False  False  False  False
# 11497  False  ...  False  False  False  False  False  False  False  False
# 11498  False  ...  False  False  False  False  False  False  False  False
# 11499  False  ...  False  False  False  False  False  False  False  False
#
#         X178      y
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 11495  False  False
# 11496  False  False
# 11497  False  False
# 11498  False  False
# 11499  False  False
#
# [11500 rows x 180 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Finding the unique values in our dependent variable

# %%
df.y.unique()
# Out:
# array([4, 1, 5, 2, 3], dtype=int64)

# %% [markdown]
# - All subjects falling in classes 2, 3, 4, and 5 are subjects who did not have epileptic seizure. Only subjects in class 1 have epileptic seizure

# %% [markdown]
# - So our aim here will to keep the output value of y=1 as it is and convert all remaining values i.e 2,3,4,5 to 0

# %% [markdown]
# #### Plotting the count of dependent variable

# %%
sns.countplot(x='OUTPUT_LABEL',data=df)
# Out:
# <AxesSubplot:xlabel='OUTPUT_LABEL', ylabel='count'>

# %% [markdown]
# - From the above plot we can say that around 20% people are having a seizure present and rest are seizure free

# %% [markdown]
# #### Finding the Correaltion

# %%
df.corr()
# Out:
#                     X1        X2        X3        X4        X5        X6  \
# X1            1.000000  0.947729  0.808192  0.608109  0.393674  0.218226
# X2            0.947729  1.000000  0.944623  0.790403  0.576579  0.369803
# X3            0.808192  0.944623  1.000000  0.939522  0.778648  0.573874
# X4            0.608109  0.790403  0.939522  1.000000  0.938636  0.784954
# X5            0.393674  0.576579  0.778648  0.938636  1.000000  0.941267
# ...                ...       ...       ...       ...       ...       ...
# X175          0.036144  0.024290  0.015536  0.016992  0.021924  0.022444
# X176          0.030581  0.023906  0.016982  0.016911  0.018869  0.020977
# X177          0.024562  0.021962  0.017070  0.014671  0.013607  0.017383
# X178          0.020022  0.018059  0.012419  0.006226  0.001298  0.004240
# OUTPUT_LABEL -0.031262 -0.024503 -0.015615 -0.002149  0.013362  0.030168
#
#                     X7        X8        X9       X10  ...      X170      X171  \
# X1            0.103693  0.044483  0.027923  0.032221  ...  0.027263  0.045401
# X2            0.211793  0.109478  0.060218  0.043565  ...  0.012602  0.025937
# X3            0.382493  0.231084  0.133249  0.080003  ...  0.004575  0.011752
# X4            0.590497  0.399855  0.250052  0.150284  ... -0.001028  0.000632
# X5            0.792304  0.596424  0.410651  0.265112  ...  0.004861  0.000918
# ...                ...       ...       ...       ...  ...       ...       ...
# X175          0.014869 -0.000510 -0.018552 -0.036517  ...  0.195640  0.366428
# X176          0.017016  0.005851 -0.009052 -0.025522  ...  0.084966  0.195891
# X177          0.018572  0.012590  0.001943 -0.011809  ...  0.022042  0.071946
# X178          0.008325  0.008032  0.004823 -0.001332  ... -0.004094  0.001945
# OUTPUT_LABEL  0.041501  0.043528  0.046100  0.052803  ...  0.001309 -0.012878
#
#                   X172      X173      X174      X175      X176      X177  \
# X1            0.051630  0.049604  0.042967  0.036144  0.030581  0.024562
# X2            0.031606  0.030452  0.025975  0.024290  0.023906  0.021962
# X3            0.016424  0.017070  0.014837  0.015536  0.016982  0.017070
# X4            0.006617  0.011882  0.014496  0.016992  0.016911  0.014671
# X5            0.006488  0.013946  0.019146  0.021924  0.018869  0.013607
# ...                ...       ...       ...       ...       ...       ...
# X175          0.573335  0.782018  0.936986  1.000000  0.933893  0.759069
# X176          0.359400  0.563321  0.767300  0.933893  1.000000  0.931826
# X177          0.175322  0.337020  0.537493  0.759069  0.931826  1.000000
# X178          0.049854  0.155044  0.315385  0.533265  0.759381  0.934330
# OUTPUT_LABEL -0.028003 -0.037840 -0.038441 -0.038926 -0.037875 -0.037212
#
#                   X178  OUTPUT_LABEL
# X1            0.020022     -0.031262
# X2            0.018059     -0.024503
# X3            0.012419     -0.015615
# X4            0.006226     -0.002149
# X5            0.001298      0.013362
# ...                ...           ...
# X175          0.533265     -0.038926
# X176          0.759381     -0.037875
# X177          0.934330     -0.037212
# X178          1.000000     -0.035855
# OUTPUT_LABEL -0.035855      1.000000
#
# [179 rows x 179 columns]

# %%
# Considering the first 15 feature cloumn
sel_features= list(df.columns[1:16])
print(sel_features)
corr = df[sel_features].corr() 
plt.figure(figsize=(12,8))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',
           xticklabels= sel_features, yticklabels= sel_features,
           cmap= 'coolwarm')
# Out:
# ['X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16']
# <AxesSubplot:>

# %% [markdown]
# # Classification of Epileptical Seizures from EEG signals using Deep Learning

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential #appropriate for a plain stack of layers
from keras.utils import np_utils # provides functions to perform actions on numpy arrays
from keras.layers import Dense, Activation , LSTM , Dropout , AveragePooling3D
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Preprocessing

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
X=df.values #return the numpy representation of the given DataFrame

# %%
X=X[:,1:-1]

# %%
from sklearn.model_selection import train_test_split


y=np.array(df['y'])
Y=np_utils.to_categorical(y) # transform your training data into vectors before you pass it to your model

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
X_train = X_train.reshape(-1,178,1)
X_test = X_test.reshape(-1,178,1)
X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
Y_train = np.asarray(Y_train).astype(np.float32)
Y_test = np.asarray(Y_test).astype(np.float32)

X_train.shape
X_test.shape
# Out:
# (2300, 178, 1)

# %% [markdown]
# ### Intuition of the Epileptical Signal In the Dataset

# %%
plt.figure(figsize=(12,8))
plt.plot(X[1,:],label='1')
plt.plot(X[7,:],label='2')
plt.plot(X[12,:],label='3')
plt.plot(X[0,:],label='4')
plt.plot(X[2,:],label='5')
plt.legend()
plt.show()

# %% [markdown]
# ### Creating LSTM Neural Network For the Classification

# %%
model = Sequential() # a way of creating deep learning models where an instance of the Sequential class 
                     # is created and model layers are created and added to it
model.add(LSTM(56, input_shape=(45,1), return_sequences=True)) #1 lstm layer is created with 56 neurons
                    # input_shape of 45 time step and 1 feature
                    # return sequence is set to True, the output of the hidden state of each neuron is used as an input to the next LSTM layer
model.add(Dropout(0.3))
model.add(LSTM(56))
model.add(Dropout(0.3))# Dropout layer randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting
model.add(Dense(20)) #it adds and hidden layer
model.add(Activation('tanh')) # Hyperbolic tangent activation function.
model.add(Dense(5))
model.add(Activation('softmax')) #Softmax converts a vector of values to a probability distribution.
                                #The elements of the output vector are in range (0, 1) and sum to 1

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 45, 56)            12992
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 45, 56)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 56)                25312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 56)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 20)                1140
# _________________________________________________________________
# activation_8 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 105
# _________________________________________________________________
# activation_9 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 39,549
# Trainable params: 39,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#loss function, this is the objective that the model will try to minimize
#metrics, classification problem you will want to set this to metrics=['accuracy']

# %%
hist = model.fit(((X_train[:,::4]-X_train.mean())/X_train.std()),Y_train[:,1:],validation_data=((X_test[:,::4]-X_test.mean())/X_test.std(),Y_test[:,1:])
                ,epochs = 50, batch_size=15,shuffle=False
                )
#The batch size is a number of samples processed before the model is updated.
#The number of epochs is a hyperparameter that defines the number times that the learning algorithm will work through the entire training dataset.
# Out:
# Epoch 1/50
# 614/614 [==============================] - 43s 61ms/step - loss: 0.4273 - accuracy: 0.3686 - val_loss: 0.3855 - val_accuracy: 0.4565
# Epoch 2/50
# 614/614 [==============================] - 33s 53ms/step - loss: 0.3806 - accuracy: 0.4461 - val_loss: 0.3756 - val_accuracy: 0.4717
# Epoch 3/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.3719 - accuracy: 0.4657 - val_loss: 0.3715 - val_accuracy: 0.4843
# Epoch 4/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.3354 - accuracy: 0.5357 - val_loss: 0.2785 - val_accuracy: 0.6452
# Epoch 5/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.2792 - accuracy: 0.6293 - val_loss: 0.2561 - val_accuracy: 0.6717
# Epoch 6/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.2572 - accuracy: 0.6601 - val_loss: 0.2496 - val_accuracy: 0.6722
# Epoch 7/50
# 614/614 [==============================] - 26s 42ms/step - loss: 0.2461 - accuracy: 0.6697 - val_loss: 0.2382 - val_accuracy: 0.6800
# Epoch 8/50
# 614/614 [==============================] - 31s 50ms/step - loss: 0.2420 - accuracy: 0.6742 - val_loss: 0.2361 - val_accuracy: 0.6904
# Epoch 9/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.2365 - accuracy: 0.6776 - val_loss: 0.2433 - val_accuracy: 0.6761
# Epoch 10/50
# 614/614 [==============================] - 32s 53ms/step - loss: 0.2336 - accuracy: 0.6897 - val_loss: 0.2351 - val_accuracy: 0.6957
# Epoch 11/50
# 614/614 [==============================] - 32s 52ms/step - loss: 0.2298 - accuracy: 0.6908 - val_loss: 0.2313 - val_accuracy: 0.6900
# Epoch 12/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.2279 - accuracy: 0.6960 - val_loss: 0.2281 - val_accuracy: 0.6983
# Epoch 13/50
# 614/614 [==============================] - 32s 52ms/step - loss: 0.2259 - accuracy: 0.6970 - val_loss: 0.2313 - val_accuracy: 0.6891
# Epoch 14/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.2220 - accuracy: 0.7000 - val_loss: 0.2250 - val_accuracy: 0.7057
# Epoch 15/50
# 614/614 [==============================] - 32s 52ms/step - loss: 0.2203 - accuracy: 0.7025 - val_loss: 0.2277 - val_accuracy: 0.7004
# Epoch 16/50
# 614/614 [==============================] - 32s 52ms/step - loss: 0.2173 - accuracy: 0.7105 - val_loss: 0.2298 - val_accuracy: 0.7022
# Epoch 17/50
# 614/614 [==============================] - 32s 53ms/step - loss: 0.2148 - accuracy: 0.7126 - val_loss: 0.2233 - val_accuracy: 0.7087
# Epoch 18/50
# 614/614 [==============================] - 32s 53ms/step - loss: 0.2146 - accuracy: 0.7109 - val_loss: 0.2261 - val_accuracy: 0.7030
# Epoch 19/50
# 614/614 [==============================] - 31s 50ms/step - loss: 0.2130 - accuracy: 0.7158 - val_loss: 0.2222 - val_accuracy: 0.7130
# Epoch 20/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.2088 - accuracy: 0.7241 - val_loss: 0.2298 - val_accuracy: 0.7091
# Epoch 21/50
# 614/614 [==============================] - 33s 55ms/step - loss: 0.2093 - accuracy: 0.7235 - val_loss: 0.2238 - val_accuracy: 0.7117
# Epoch 22/50
# 614/614 [==============================] - 33s 53ms/step - loss: 0.2052 - accuracy: 0.7275 - val_loss: 0.2497 - val_accuracy: 0.7074
# Epoch 23/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.2083 - accuracy: 0.7289 - val_loss: 0.2294 - val_accuracy: 0.7113
# Epoch 24/50
# 614/614 [==============================] - 32s 52ms/step - loss: 0.2023 - accuracy: 0.7313 - val_loss: 0.2181 - val_accuracy: 0.7183
# Epoch 25/50
# 614/614 [==============================] - 32s 53ms/step - loss: 0.2020 - accuracy: 0.7333 - val_loss: 0.2181 - val_accuracy: 0.7183
# Epoch 26/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1980 - accuracy: 0.7388 - val_loss: 0.2215 - val_accuracy: 0.7226
# Epoch 27/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1956 - accuracy: 0.7425 - val_loss: 0.2167 - val_accuracy: 0.7243
# Epoch 28/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1959 - accuracy: 0.7460 - val_loss: 0.2147 - val_accuracy: 0.7217
# Epoch 29/50
# 614/614 [==============================] - 34s 56ms/step - loss: 0.1946 - accuracy: 0.7461 - val_loss: 0.2141 - val_accuracy: 0.7239
# Epoch 30/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1923 - accuracy: 0.7475 - val_loss: 0.2180 - val_accuracy: 0.7248
# Epoch 31/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.1953 - accuracy: 0.7438 - val_loss: 0.2256 - val_accuracy: 0.7183
# Epoch 32/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1904 - accuracy: 0.7527 - val_loss: 0.2193 - val_accuracy: 0.7335
# Epoch 33/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1875 - accuracy: 0.7567 - val_loss: 0.2238 - val_accuracy: 0.7196
# Epoch 34/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1864 - accuracy: 0.7609 - val_loss: 0.2260 - val_accuracy: 0.7126
# Epoch 35/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1839 - accuracy: 0.7650 - val_loss: 0.2226 - val_accuracy: 0.7217
# Epoch 36/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1819 - accuracy: 0.7708 - val_loss: 0.2192 - val_accuracy: 0.7265
# Epoch 37/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1823 - accuracy: 0.7701 - val_loss: 0.2164 - val_accuracy: 0.7261
# Epoch 38/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1791 - accuracy: 0.7704 - val_loss: 0.2238 - val_accuracy: 0.7204
# Epoch 39/50
# 614/614 [==============================] - 33s 53ms/step - loss: 0.1798 - accuracy: 0.7739 - val_loss: 0.2238 - val_accuracy: 0.7209
# Epoch 40/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1757 - accuracy: 0.7813 - val_loss: 0.2259 - val_accuracy: 0.72570s - loss: 0
# Epoch 41/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1771 - accuracy: 0.7776 - val_loss: 0.2212 - val_accuracy: 0.7313
# Epoch 42/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1760 - accuracy: 0.7778 - val_loss: 0.2244 - val_accuracy: 0.7191
# Epoch 43/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1769 - accuracy: 0.7840 - val_loss: 0.2160 - val_accuracy: 0.7383
# Epoch 44/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1682 - accuracy: 0.7927 - val_loss: 0.2201 - val_accuracy: 0.7291
# Epoch 45/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1681 - accuracy: 0.7937 - val_loss: 0.2177 - val_accuracy: 0.7478
# Epoch 46/50
# 614/614 [==============================] - 33s 54ms/step - loss: 0.1691 - accuracy: 0.7970 - val_loss: 0.2281 - val_accuracy: 0.7265
# Epoch 47/50
# 614/614 [==============================] - 33s 55ms/step - loss: 0.1650 - accuracy: 0.8008 - val_loss: 0.2195 - val_accuracy: 0.7404
# Epoch 48/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1660 - accuracy: 0.7999 - val_loss: 0.2239 - val_accuracy: 0.7443
# Epoch 49/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1620 - accuracy: 0.8059 - val_loss: 0.2223 - val_accuracy: 0.7470
# Epoch 50/50
# 614/614 [==============================] - 34s 55ms/step - loss: 0.1609 - accuracy: 0.8053 - val_loss: 0.2180 - val_accuracy: 0.7370

# %% [markdown]
# ### Saving the trained model

# %%
model.save('Epilepsy.h5')

# %% [markdown]
# ### Visualization

# %% [markdown]
# - Graph Between Training Loss and Training Accuracy

# %%
plt.figure(0)
plt.plot(hist.history['loss'],'g')
plt.plot(hist.history['accuracy'],'r')
plt.show()

# %% [markdown]
# - Graph Between Validation Loss Function and Validation Accuracy

# %%
plt.figure(0)
plt.plot(hist.history['val_loss'],'b')
plt.plot(hist.history['val_accuracy'],'black')
plt.show()
